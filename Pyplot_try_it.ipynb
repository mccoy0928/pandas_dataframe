# %% [markdown]
# <a href="https://colab.research.google.com/github/mccoy0928/pandas_dataframe/blob/main/Pyplot_try_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pyplot 介紹操作
# * 語法說明：
# plot( )可以用於繪製圖上的點，它會採用參數中被我們指定的點
# (x, y)參數等同於點的陣列，第一個參數x是包含x 軸上點的陣列；第二個參數y 是包含y 軸上點的陣列

# %%
import matplotlib.pyplot as plt

import numpy as np

xpoints = np.array([0, 3])

ypoints = np.array([0, 150])

plt.plot(xpoints, ypoints)

plt.show()

# %%
# 標記座標、不連線繪圖
xpoints = np.array([1, 5])

ypoints = np.array([3, 7])

plt.plot(xpoints, ypoints, 'o')

plt.show()

# %% [markdown]
# ## 繪製多個點
# * 可以繪製無限多點，只需要確定x軸與y軸的個數是成對的

# %%
xpoints = np.array([1, 2, 6, 8])

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

plt.show()

# %% [markdown]
# * 標記
# 可以使用關鍵字參數 maker 的指定標記來強調每個點，可以用上面提過的 ‘o’、’ * ‘

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')

plt.show()

# %% [markdown]
# * 除了點的標記外，線的格式與顏色也可以做修改，稱為字串表示法 fmt，它的格式是 標記 | 線 | 顏色

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')

plt.show()

# %% [markdown]
# * 同一圖表中呈現多條線
# 如果想要在同一張圖畫上多條線的話，只需要新增不同的陣列即可繪製不同條線 plt.plot()

# %%
x1 = np.array([0, 1, 2, 3])

y1 = np.array([3, 8, 1, 10])

x2 = np.array([0, 1, 2, 3])

y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)

plt.show()

# %% [markdown]
# # 繪製多個圖表
# * 如果想要繪製多個圖表，可以使用subplots(行,列,第幾個圖)

# %%
#plot 1:

x = np.array([0, 1, 2, 3])

y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)	#一行，兩列，第一個圖表

plt.plot(x,y)

#plot 2:

x = np.array([0, 1, 2, 3])

y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)	#一行，兩列，第二個圖表

plt.plot(x,y)

plt.show()

# %%
#plot 1:

x = np.array([0, 1, 2, 3])

y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1) #兩行，一列，第一個圖表

plt.plot(x,y)

#plot 2:

x = np.array([0, 1, 2, 3])

y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2) #兩行，一列，第二個圖表

plt.plot(x,y)

plt.show()

# %% [markdown]
# # 將圖表加入標題
# * 使用title( )可以幫圖表加上標題、suptitle()可以幫整個圖表加上主標題

# %% [markdown]
# # 繪製柱狀圖
# * 使用bar(類別,值 )即可繪製垂直的柱狀圖

# %%
x = np.array(["A", "B", "C", "D"])

y = np.array([3, 8, 1, 10])
plt.title('Test Bar char')
plt.suptitle('Main char')

plt.bar(x,y)

plt.show()

# %%
# 使用barh( )，即可繪製水平的柱狀圖，color可以選擇柱狀圖的顏色，width可以調整寬度，預設的寬度是0.8

x = np.array(["A", "B", "C", "D"])

y = np.array([3, 8, 1, 10])

# plt.bar(x, y, color='g', width = 0.1)
plt.barh(x, y, color='g')
plt.show()

# %% [markdown]
# # 繪製直方圖
# * 直方圖可以表示次數分配，hist( )

# %%
x = np.random.normal(170, 10, 250)		#隨機生成一個250個介於170左右的值，標準差為10

plt.hist(x)

plt.show()

# %% [markdown]
# # 繪製圓餅圖
# * 使用pie( )可繪製圓餅圖，預設會從圓餅圖中間的右手邊開始，逆時針分配比例。

# %%
y = np.array([15, 35, 15, 35])

plt.pie(y)

plt.show()

# %%
# 可使用lables來添加標籤，或是想要改變開始的角度，可以使用startangle，角度如下圖所示：

y = np.array([15, 35, 15, 35])

mylabels = ["ants", "birds", "cats", "dogs"]

plt.pie(y, labels = mylabels, startangle = 90)

plt.show()

# %%
# 如果你想要其中一個比例比較明顯，可以使用explode[預設為0，調整值可以改變每個比例距離圖形的圓心有多遠]

y = np.array([15, 35, 15, 35])

mylabels = ["ants", "birds", "cats", "dogs"]

myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)

plt.show()

# %%
# 將圓餅圖加入陰影，可以用shadow = True，也可以改變圓餅圖的顏色 colors
y = np.array([15, 35, 15, 35])

mylabels = ["ants", "birds", "cats", "dogs"]

myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)

plt.show()

# %% [markdown]
# ## 使用legend( )可以加入圖例，使用title可以添加圖例的標題

# %%
y = np.array([15, 35, 15, 35])

mylabels = ["ants", "birds", "cats", "dogs"]

plt.pie(y, labels = mylabels)

plt.legend(title = "Four animals:")

plt.show()
